# %%
#SEARCHING IN TUPLE

# %%
newtuple = tuple("abcde")

# %%
print(newtuple)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
print("f" in newtuple)
# Out:
# False

# %%
print("e" in newtuple)
# Out:
# True

# %%
print(newtuple.index('b'))
# Out:
# 1

# %%
#custom method

# %%
def search (tuplee , element):
    for i in range (0,len(tuplee)):
        if tuplee[i]==element:
            return f"The {element} is not found at{i} index"
        return "The element is not found"
print(search(newtuple ,'f'))
# Out:
# The element is not found

# %%
def search (tuplee , element):
    for i in range (0,len(tuplee)): #------O(N)
        if tuplee[i]==element:       #------O(1)
            return f"The { element } is  found at { i } index"  #------O(1)
    return "The element is not found" #------O(1)
print(search(newtuple ,'a'))          #------O(1)
# Out:
# The a is  found at 0 index

# %%
#TC = O(N)
#SC = O(1)
