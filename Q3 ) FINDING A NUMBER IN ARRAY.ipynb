# %%
#Q3 ) FINDING A NUMBER IN ARRAY

# %%
import numpy as np

# %%
myarray = [1,2,3,4,6,5,7,9]

# %%
def findinarray (array , num):
    for i in range (len(array)):
        if array [i] ==num:
            return (i)

# %%
findinarray(myarray ,3)
# Out:
# 2
