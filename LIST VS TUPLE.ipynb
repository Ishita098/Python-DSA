# %% [markdown]
# # LIST V/S TUPLE
# LIST IS MUTABLE , WHEREAS A TUPLE IS IMMUTABLE

# %%
#reassiging a list

# %%
list1 = [0,1,2,3,4,5,6,7,8]

# %%
list1[1]=3

# %%
print(list1)
# Out:
# [0, 3, 2, 3, 4, 5, 6, 7, 8]

# %%
list1 = [7,6,3,2,5,4] #reassinging

# %%
print(list1)
# Out:
# [7, 6, 3, 2, 5, 4]

# %%
del list1 [0] #deleting

# %%
print(list1)
# Out:
# [(3, 4)]

# %%
#TUPLE

# %%
tuple1 = 0,1,2,3,4,5,6,7,8

# %%
tuple[1]=3
print(tuple1)
#tuple does not allow item assignment i.e immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 tuple[1]=3
#       2 print(tuple1)
#
# TypeError: 'type' object does not support item assignment

# %%
tuple1 = 7,8,91 
print(tuple1) #we can reassign whole tuple but can not mutate a tuple
# Out:
# (7, 8, 91)

# %%
#deleting

# %%
del tuple1[0] #either the whole tuple will be deleted ,but we cannot delete a single element
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 del tuple1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
#FUNCTIONS both list and tuple perform- len() ,max(),min(),any(),all(),sorted()

# %%
#METHODS both list and tuple use = count() , index()

# %%
#METHODS ONLY FOR LIST 
'''append ()
insert ()
remove()
pop()
clear()
sort()
reverse()'''
# Out:
# 'append ()\ninsert ()\nremove()\npop()\nclear()\nsort()\nreverse()'

# %% [raw]
# -Tuples can be stored in lists
# -Lists can be stored in tuple

# %%
list1= [(1,2),(3,4)]
print(list1)
# Out:
# [(1, 2), (3, 4)]

# %%
tuple1 = ([1,2],[3,4])
print(tuple1)
# Out:
# ([1, 2], [3, 4])

# %% [raw]
# -BOTH TUPLES AND LIST CAN BE NESTED

# %% [raw]
# -we generally use tuples for heterogenous (diff) data types and lists  for homogenous (similar) data types.
# - Iterating through a tuple is faster than with list
# -Tuples that contain immutable elements can be used as a key for a dictionary.
# - If you have data that doesn't change , implementing it as tuple will gaurentee that it remains write- protected.

# %%
#WRITE TIME C AND SPACE.C FROM SLIDE.
