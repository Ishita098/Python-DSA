# %%
#Q6 ) PERMUTATION OF STRING i.e LIAR =RAIL

# %%
def permutation (list1 ,list2):
    if len(list1)!=len(list2):
        return False 
    list1.sort()
    list2.sort()
    if list1 ==list2:
        True
    else:
        return False

# %%
l1 =[1,2,3]

# %%
l2 =[3,1,]

# %%
permutation(l1 , l2)
# Out:
# False
