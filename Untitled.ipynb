# %%
#CREATE A TUPLE

# %%
newtuple = ('a','b','c','d','e')
print(newtuple)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
#when we have creat a single char string its necessary to put a comma in between

# %%
newtuple1 = ("a",)
print(newtuple1)
# Out:
# ('a',)

# %%
newtuple1 = ("a")
print(newtuple1)
# Out:
# a

# %%
newtuple1 =tuple ()
print(newtuple1)
# Out:
# ()

# %%
newtuple1 =tuple ('abcde')
print(newtuple1)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
#TIME .C= O(1)
#SPACE.C =O(n)
