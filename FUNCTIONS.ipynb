# %%
#FUNCTIONS

# %%
#ALL
mydict = {0:True , 1:False ,2:False}
print(all(mydict))
# Out:
# False

# %%
mynewdict = {0:True , 1:True}
print(all(mynewdict))
# Out:
# False

# %%
#any

# %%
mydict = {0:True , 1:False ,2:False}
newdict ={}
print(any(newdict))
# Out:
# False

# %%
#len

# %%
print(len(mydict))
# Out:
# 3

# %%
newdict = {"a":1,"aaaaaa":2,"aaaa":3,"aaa":4}
print(sorted(newdict,key=len))
# Out:
# ['a', 'aaa', 'aaaa', 'aaaaaa']

# %%
newdict = {"a":1,"aa":2,"aaa":3,"aaaa":4}
print(sorted(newdict,reverse=True,key=len))
# Out:
# ['aaaa', 'aaa', 'aa', 'a']
