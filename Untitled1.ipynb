# %%
#ACCESSING AN ELEMENT

# %%
newtulple= tuple("abcdef")
print(newtulple)
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
print(newtulple[1])
# Out:
# b

# %%
print(newtulple[-1])
# Out:
# f

# %%
print(newtulple[1:3])
# Out:
# ('b', 'c')

# %%
print(newtulple[:3])
# Out:
# ('a', 'b', 'c')

# %%
print(newtulple[:])
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
print(newtulple[1:])
# Out:
# ('b', 'c', 'd', 'e', 'f')

# %%
print(newtulple[1:-1])
# Out:
# ('b', 'c', 'd', 'e')

# %%
newtulple [0]="f"
#coz tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 newtulple [0]="f"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#TRAVERSE A TUPLE

# %%
print(newtulple)
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
for i in newtulple:
     print(i)
# Out:
# a
# b
# c
# d
# e
# f

# %%
for i in range(len)
