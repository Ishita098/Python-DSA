# %%
#DICTIONARY METHODS

# %%
mydict ={"1":"one","2":"two","3":"three","4":"four"}

# %%
mydict.clear()
print(mydict)
# Out:
# {}

# %%
mydict ={"1":"one","2":"two","3":"three","4":"four"}

# %%
"""dict=mydict.copy()
print(mydict)
print(dict)"""
# Out:
# 'dict=mydict.copy()\nprint(mydict)\nprint(dict)'

# %%
newdict = {}.fromkeys([1,2,3],0)
print(newdict)
# Out:
# {1: 0, 2: 0, 3: 0}

# %%
print(mydict.get("1","five"))
# Out:
# one

# %%
print(mydict.items())
# Out:
# dict_items([('1', 'one'), ('2', 'two'), ('3', 'three'), ('4', 'four')])

# %%
print(mydict.keys())
# Out:
# dict_keys(['1', '2', '3', '4'])

# %%
print(mydict.values())
# Out:
# dict_values(['one', 'two', 'three', 'four'])

# %%
print(mydict.popitem())
# Out:
# ('4', 'four')

# %%
print(mydict)
# Out:
# {'1': 'one', '2': 'two', '3': 'three'}

# %%
print(mydict.setdefault('1','added'))
# Out:
# one

# %%
print(mydict.setdefault('11','added'))
# Out:
# added

# %%
mydict
# Out:
# {'1': 'one', '2': 'two', '3': 'three', '11': 'added'}

# %%
print(mydict.pop('nzame','not'))
# Out:
# not

# %%
newdict = {"one":"zuzu","two":"titu"}
mydict.update(newdict)
print(mydict)
# Out:
# {'2': 'two', '3': 'three', '11': 'added', 'one': 'zuzu', 'two': 'titu'}

# %%
mydict = {'2': 'two', '3': 'three', '11': 'added', 'one': 'zuzu', 'two': 'titu'}

# %%
print("two" in mydict.values())
# Out:
# True

# %%
print("3" in mydict)
# Out:
# True

# %%
for key in mydict:
    print (key,mydict[key])
# Out:
# 2 two
# 3 three
# 11 added
# one zuzu
# two titu
