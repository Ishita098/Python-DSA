# %%
#ARRAY TRAVERSAL

# %%
from array import*
array1 = array('i',[1,2,3,4,5,6])

def traversearray(array):
    for i in array:
        print(i)
traversearray(array1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
from array import*
array1 = array('i',[1,2,3,4,5])

def traversearray(array):
    for i in array:
        print(i)
traversearray(array1)
# Out:
# 1
# 2
# 3
# 4
# 5
