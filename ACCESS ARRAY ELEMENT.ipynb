# %%
#ACCESS ARRAY ELEMENT

# %%
from array import*

# %%
arr1 = array('i',[1,2,3,4,5,6])
def accesselement(array,index):
    if index>=len(array):
        print("The element does not lie at this index")
    else:
        print(array[index])
accesselement(arr1,5)
# Out:
# 6
