# %%
#Q5 ) IS UNIQUE = IMPLEMENT AN ALGORITHM TO DETERMINE THE UNIQUE ELEMENTS WHILE TRAVERSING THE LIST i.e EVERY ELEMENT IS UNIQUE FROM ANOTHER

# %%
mylist = [1,220,3,5,63,4,8,9,6,7,69,45,12]

# %%
def  unique(list):
    a= []
    for i in list:
        if i in a:
            print(i)
            return False 
        else :
            a.append(i)
    return True
print (unique(mylist))
# Out:
# True
